# %%
import pandas as pd
from utils.requests_utils import *

# %%
data = inegi_denue_search_places(method='Buscar',
                                 key_word='restaurantes',
                                 latitude=19.430672,
                                 longitude=-99.196956,
                                 radio=1000)

# %%
df = pd.DataFrame(data)
print(df.shape)
df.head()
# Out:
# (327, 22)
#                            CLEE       Id               Nombre  \
# 0  09016722511005663000000000U0  7444731               EUCAPA
# 1  09016722511006483000000000U2  9137994  RESTAURANTE ATIPICO
# 2  09016722219007011011000000U0   762647             CONFETTI
# 3  09016722511004731000000000U6  8646416                NAHNU
# 4  09016722511004963000000000U5  7983023          SUSHI BATTA
#
#                      Razon_social  \
# 0                         EUCAPA
# 1                        ATIPICO
# 2  GASTRONOMICA CONFETTI SA DE CV
# 3                          NAHNU
# 4       GERMIE ALIMENTOS SA DE CV
#
#                                      Clase_actividad           Estrato  \
# 0  Restaurantes con servicio de preparación de al...  11 a 30 personas
# 1  Restaurantes con servicio de preparación de al...  11 a 30 personas
# 2  Restaurantes con servicio de preparación de al...    0 a 5 personas
# 3  Restaurantes con servicio de preparación de al...    0 a 5 personas
# ...

# %%
df[df['Nombre'].str.lower().str.contains('sushi')]
# Out:
#                              CLEE       Id               Nombre  \
# 4    09016722511004963000000000U5  7983023          SUSHI BATTA
# 27   09016722110001073000021918S7   762660           SUSHI ROLL
# 38   09016722511005193000045349S8  8596056           SUSHI ITTO
# 58   09016722110004093000028189M2  6794375     MR SUSHI MASARYK
# 133  09016722110001133000000000U9   763073       PUBBELLY SUSHI
# 223  09016722511002063001000000U6   689881  SUSHI BAR TEPANYAKI
# 234  09016722511000443000000000U2   737529              SUSHITO
#
#                           Razon_social  \
# 4            GERMIE ALIMENTOS SA DE CV
# 27                 SUSHI ROLL SA DE CV
# 38     SUSHI ITTO MEXICO S DE RL DE CV
# 58           RENTASU MEXICANA SA DE CV
# 133    SASORI PUBELLY LATINO  SA DE CV
# 223     GASTRONOMICA TAKENOYA SA DE CV
# 234  VIEJO RINCON DE COYOACAN SA DE CV
#
#                                        Clase_actividad             Estrato  \
# ...

# %%
df[(df['Nombre'].str.lower().str.contains('mandolina')) | (df['Razon_social'].str.lower().str.contains('mandolina'))]
# Out:
# Empty DataFrame
# Columns: [CLEE, Id, Nombre, Razon_social, Clase_actividad, Estrato, Tipo_vialidad, Calle, Num_Exterior, Num_Interior, Colonia, CP, Ubicacion, Telefono, Correo_e, Sitio_internet, Tipo, Longitud, Latitud, CentroComercial, TipoCentroComercial, NumLocal]
# Index: []
#
# [0 rows x 22 columns]

# %%
df[(df['Nombre'].str.lower().str.contains('japo')) | (df['Razon_social'].str.lower().str.contains('japo'))]
# Out:
#                              CLEE       Id     Nombre          Razon_social  \
# 104  09016722511007315000000000U5  9348127  ROSANEGRA  TORAJAPONES SA DE CV
#
#                                        Clase_actividad            Estrato  \
# 104  Restaurantes con servicio de preparación de al...  51 a 100 personas
#
#     Tipo_vialidad               Calle Num_Exterior Num_Interior  ...  \
# 104       AVENIDA  PRESIDENTE MASARYK          298               ...
#
#                                             Ubicacion Telefono Correo_e  \
# 104  MIGUEL HIDALGO, Miguel Hidalgo, CIUDAD DE MÉXICO
#
#             Sitio_internet  Tipo      Longitud      Latitud CentroComercial  \
# 104  WWW.ROSANEGRA..COM.MX  Fijo  -99.19341365  19.43140867
#
#     TipoCentroComercial NumLocal
# 104
#
# [1 rows x 22 columns]

# %%
df[(df['Nombre'].str.lower().str.contains('japo')) | (df['Razon_social'].str.lower().str.contains('japo'))]['Clase_actividad']
# Out:
# 104    Restaurantes con servicio de preparación de al...
# Name: Clase_actividad, dtype: object

# %%
data = inegi_denue_search_places(method='Cuantificar',
                                 economic_activity=71,
                                 geo_area='01',
                                 estrato=0)

# df = pd.DataFrame(data)
# print(df.shape)
# df.head()

# %%
data
# Out:
# [{'AE': '71', 'AG': '01', 'Total': '767'}]
